# %% [markdown]
# # Get Started
#
# ## Installation
#
# If you haven't already, check out the [installation guide](installation.html) to get Bingo setup.

# %% [markdown]
# ## Running an Example
#
# Let's run a quick example to ensure that the installation works properly.

# %% [markdown]
# ### Creating Training Data

# %%
import numpy as np
X = np.linspace(-10, 10).reshape((-1, 1))
y = 3.0 * X ** 2 - 2.0 * X

# %% [markdown]
# ### Visualizing Training Data

# %%
import matplotlib.pyplot as plt
plt.scatter(X, y)
plt.xlabel("X_0")
plt.ylabel("y")
plt.title("Training Data")
plt.show()

# %% [markdown]
# ### Fitting a Model

# %%
from bingo.symbolic_regression.symbolic_regressor import SymbolicRegressor
regressor = SymbolicRegressor()
regressor.fit(X, y)
print("Found model:", regressor.get_best_individual())
pred_y = regressor.predict(X)
# Out:
# /home/runner/work/bingo/bingo/bingo/symbolic_regression/__init__.py:31: UserWarning: Could not load C++ modules No module named 'bingocpp.build'
#   warnings.warn(f"Could not load C++ modules {import_err}")
# Found model: ((X_0)(1.0 + 1.0) + X_0)((1.0 + 1.0)(1.0 + 1.0 + -2.4166666666666665) + (1.0 + 1.0)(1.0 + 1.0 + -2.4166666666666665) + X_0 + 1.0)

# %% [markdown]
# ### Visualizing the Model's Predictions

# %%
plt.scatter(X, y)
plt.scatter(X, pred_y)
plt.xlabel("X_0")
plt.ylabel("y")
plt.legend(["actual", "predicted"])
plt.show()
